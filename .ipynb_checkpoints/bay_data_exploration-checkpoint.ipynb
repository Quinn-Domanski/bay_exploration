# %% [markdown]
# # Chesapeake Bay Data Exploration
#
# By: Quinn Domanski
#
# ## What's going on with the Chesapeake Bay?
#
# ### Question:
#
# Since 1984, sites have been set up around the bay to monitor multiple paramters that could effect the health of The Chesapeake Bay. The health of The Chesapeake Bay refers to the Bay's ability to support diverse aquatic life, through it's intricate natural systems. Some of these parameters include, Temperature ( &deg;C ), Salinity (ppt),  and pH. One important paramter is Total Nitrogen (TN) and Nitrate/Nitrite (NO23), as both of these can cause major problems to the health of the Chesapeake Bay, with an excess of these paramters causing massive algal blooms which consume oxygen creating dead zones (areas with low dissolved oxygen (DO) where marine life can't survive). We want to know:
#
# **What causes increased levels of Total Nitrogen and Nitrate/Nitrite?**
#
# In this notebook, we analyze parameters that could be correlated to Total Nitrogen and Nitrate/Nitrite, to identify if we can find a trend that causes these to increase. By detecting these patterns we hope to find out what could be causing high levels of both of these in the Bay. This leads us to an overarching question of:
#
# **Can we find a correlation between any of the paramters that are recorded, including geographic features and nutrient levels?**
#
# Dataset Used:
#
# * https://eyesonthebay.dnr.maryland.gov/bay_cond/LongTermData.cfm: Data from 1984 - 2024/12/16
# * https://eyesonthebay.dnr.maryland.gov/bay_cond/LongTermStationInfoTable.cfm
# * https://data-maryland.opendata.arcgis.com/datasets/b696bc3212c840448c3bf8a2172997f3_5/explore?location=38.169388%2C-75.706570%2C9 - Geographic Data
#
# Map of stations:
# * https://eyesonthebay.dnr.maryland.gov/bay_cond/img/map_of_mainstem_and_tributary_monitoring_stations.pdf

# %%
import pandas as pd
from datetime import datetime
import os.path
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
import geopandas as gpd
import contextily as cx

# %% [markdown]
# ### Load The Data

# %%
if not os.path.exists("data/all_data.csv"):
    print("does not exist")
    all_data = pd.read_csv("data/station_0_3.csv")
    for i in range(3, 93, 3):
        try:
            cur_csv = pd.read_csv(f"data/station_{i}_{i+3}.csv")
        except:
            if i == 90:
                cur_csv = pd.read_csv(f"data/station_90_91.csv")
                print("last\n")
            else:
                continue
        all_data = pd.concat([all_data, cur_csv])
    all_data.to_csv("data/all_data.csv")
else:
    print("exists")
    all_data_original = pd.read_csv("data/all_data.csv")
all_data_original.head()
# Out:
# exists
# /tmp/ipykernel_6321/2836962627.py:17: DtypeWarning: Columns (0: BiasPC, 1: Details) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_data_original = pd.read_csv("data/all_data.csv")
#    Unnamed: 0 MonitoringStation   EventId  Cruise Program Project Agency  \
# 0           0             CB1.0   99182.0  BAY500    TWQM    TRIB  MDDNR
# 1           1             CB1.0   99182.0  BAY500    TWQM    TRIB  MDDNR
# 2           2             CB1.0   99598.0  BAY502    TWQM    TRIB  MDDNR
# 3           3             CB1.0   99598.0  BAY502    TWQM    TRIB  MDDNR
# 4           4             CB1.0  100147.0  BAY504    TWQM    TRIB  MDDNR
#
#   Source Station SampleDate  ...  Unit  Method    Lab  Problem  PrecisionPC  \
# 0  MDDNR   CB1.0   3/4/2009  ...  UG/L    L01   MDHMH      NaN          NaN
# 1  MDDNR   CB1.0   3/4/2009  ...  UG/L    L01   MDHMH      NaN          NaN
# 2  MDDNR   CB1.0   4/6/2009  ...  UG/L    L01   MDHMH      NaN          NaN
# ...

# %%
all_data_original.shape
# Out:
# (5067315, 31)

# %% [markdown]
# ### General Cleaning:
# Some of the data is not needed for this project for various reasons, here is where it is removed.

# %% [markdown]
# #### Qualifiers:
# If the data has the qualifier '>' (qualifier id of 2), it means that the concentration not quantified, exceeds the given value and can be unrelible, to ensure it does not skew the data matching rows are removed.

# %%
#Remove Qualifiers == '>' form dataframe
clean_qualifiers = all_data_original[all_data_original['Qualifier'].str.strip() != '>']
print(f"We lost {all_data_original.shape[0] - clean_qualifiers.shape[0]} rows from the original dataframe. We have {clean_qualifiers.shape[0]} remaining.")
# Out:
# We lost 123 rows from the original dataframe. We have 5067192 remaining.

# %% [markdown]
# #### Program:
# We want to remove any data from the Nontidal Water Quality Monitoring Program (NTWQM). We are focusing on mainly tidal waterways connected to the Bay. This includes stations POT1184, TF1.0, TF1.2, GUN0125, POT1830.
# *See included map for details about stations*

# %%
#Remove Program == 'NTWQM'
clean_program = clean_qualifiers[clean_qualifiers['Program'].str.strip() != 'NTWQM']
print(f"We lost {clean_qualifiers.shape[0] - clean_program.shape[0]} rows. We have {clean_program.shape[0]} remaining.")
# Out:
# We lost 81940 rows. We have 4985252 remaining.

# %% [markdown]
# #### Sample Replicate:
# Some sample replicate types should not be included like controls (CTRL), field blanks (FB), or equipment and filtration blank (EB). These are good for quality control but not useful data for our purposes.

# %%
#Remove SampleReplicateTypes that are in the remove list
rep_remove_list = ['CTRL', 'FB', 'EB', 'SPK', 'SPK1', 'SPK2', 'SWB', 'LAB']
clean_replicate = clean_program[~clean_program['SampleReplicateType'].str.strip().isin(rep_remove_list)]
print(f"We lost {clean_program.shape[0] - clean_replicate.shape[0]} rows. We have {clean_replicate.shape[0]} remaining.")
#Cool none of them exist in the dataset.
# Out:
# We lost 0 rows. We have 4985252 remaining.

# %% [markdown]
# #### Parameters:
# Some parameters are not needed for this project, biogenic silica (BIOSI) is not within the scope of this project, silica as filtered (SIF), or any row with a NAN value for parameter can be removed.

# %%
#Remove parameters
param_remove_list = ['BIOSI', 'SIF']
clean_param = clean_replicate[~clean_replicate['Parameter'].str.strip().isin(param_remove_list)]
clean_param = clean_param[clean_param['Parameter'].notna()]
print(f"We lost {clean_replicate.shape[0] - clean_param.shape[0]} rows. We have {clean_param.shape[0]} remaining.")
# Out:
# We lost 92101 rows. We have 4893151 remaining.

# %% [markdown]
# #### Problem:
# The problem columns is used to show if there was some kind of problem while collecting or processing the data. Some of these problems are significant and rows matching these problems should be removed. Particularly, instrument failure (C), cannot calculate given available data (CC), insuficient sample (D), incorrect sample fraction for analysis (J), sample comtaminated (R), no sample recieved by lab from field office (RR), Sample rejected due to high suspended sediment concentration (SS), sample results rejected due to QC criteria (V), laboratory accident (A), field accident (AA) and chemical matrix interference (B).

# %%
prob_remove_list = ['C', 'CC', 'D', 'J', 'R', 'RR', 'SS', 'V', 'A', 'AA', 'B']
clean_problem = clean_param[~clean_param['Problem'].str.strip().isin(prob_remove_list)]
print(f"We lost {clean_param.shape[0] - clean_problem.shape[0]} rows. We have {clean_problem.shape[0]} remaining.")
# Out:
# We lost 25769 rows. We have 4867382 remaining.

# %% [markdown]
# #### Cleaning Columns:
# Some columns are not needed for further analysis and can be removed to save compute resources moving forward. These columns include, Cruise, Program, Project, Agency, Source, Station, UpperPycnocline, LowerPycnocline, Qualifier, Method, Lab, Problem, PrecisionPC, BiasPC, Details, and TierLevel.

# %%
cleaned_data = clean_problem.drop(columns = ['Cruise', 'Program', 'Project', 'Agency', 'Source', 'Station', 'UpperPycnocline', 'LowerPycnocline', 'Qualifier', 'Method', 'Lab', 'Problem', 'PrecisionPC', 'BiasPC', 'Details', 'TierLevel'])
cleaned_data.columns
# Out:
# Index(['Unnamed: 0', 'MonitoringStation', 'EventId', 'SampleDate',
#        'SampleTime', 'TotalDepth', 'Depth', 'Layer', 'SampleType',
#        'SampleReplicateType', 'Parameter', 'MeasureValue', 'Unit', 'Latitude',
#        'Longitude'],
#       dtype='str')

# %%
cleaned_data.head()
# Out:
#    Unnamed: 0 MonitoringStation   EventId SampleDate SampleTime  TotalDepth  \
# 0           0             CB1.0   99182.0   3/4/2009   09:26:00         NaN
# 1           1             CB1.0   99182.0   3/4/2009   09:26:00         NaN
# 2           2             CB1.0   99598.0   4/6/2009   09:55:00         NaN
# 3           3             CB1.0   99598.0   4/6/2009   09:55:00         NaN
# 4           4             CB1.0  100147.0   5/5/2009   10:32:00         NaN
#
#    Depth Layer SampleType SampleReplicateType Parameter  MeasureValue  Unit  \
# 0    0.0    S           D                 FS1      CHLA          2.03  UG/L
# 1    0.0    S           D                 FS2      CHLA          2.03  UG/L
# 2    0.0    S           D                 FS1      CHLA         17.73  UG/L
# 3    0.0    S           D                 FS2      CHLA         17.94  UG/L
# 4    0.0    S           D                 FS1      CHLA         11.75  UG/L
#
#    Latitude  Longitude
# 0  39.65622  -76.17504
# ...

# %% [markdown]
# ### Correcting DataTypes:
# Ensure that all of the columns have correct datatypes that allow for them to correctly be processed. MeasrureValue, Depth, Longitude, and Latitude are all numeric values and should be converted using pd.to_numeric. SampleDate and SampleTime can be combined into a single column that can be date time.

# %%
#Check current column types
cleaned_data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 4867382 entries, 0 to 5067313
# Data columns (total 15 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   Unnamed: 0           int64
#  1   MonitoringStation    str
#  2   EventId              float64
#  3   SampleDate           str
#  4   SampleTime           str
#  5   TotalDepth           float64
#  6   Depth                float64
#  7   Layer                str
#  8   SampleType           str
#  9   SampleReplicateType  str
#  10  Parameter            str
#  11  MeasureValue         float64
#  12  Unit                 str
#  13  Latitude             float64
#  14  Longitude            float64
# dtypes: float64(6), int64(1), str(8)
# memory usage: 594.2 MB

# %%
#Fix SampleDate and SampleTime into one DateTime Column
cleaned_data['Datetime'] = pd.to_datetime(
    cleaned_data['SampleDate'].astype(str) + ' ' + cleaned_data['SampleTime'].astype(str),
    errors='coerce'
)
cleaned_data['Datetime'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No NATs is very good, it shows a very clean dataset, and no errors from cleaned_data.

# %%
#Now that we have Datetime, remove SampleDate and SampleTime
cleaned_data = cleaned_data.drop(columns = ['SampleDate', 'SampleTime'])
cleaned_data.head()
# Out:
#    Unnamed: 0 MonitoringStation   EventId  TotalDepth  Depth Layer SampleType  \
# 0           0             CB1.0   99182.0         NaN    0.0    S           D
# 1           1             CB1.0   99182.0         NaN    0.0    S           D
# 2           2             CB1.0   99598.0         NaN    0.0    S           D
# 3           3             CB1.0   99598.0         NaN    0.0    S           D
# 4           4             CB1.0  100147.0         NaN    0.0    S           D
#
#   SampleReplicateType Parameter  MeasureValue  Unit  Latitude  Longitude  \
# 0                 FS1      CHLA          2.03  UG/L  39.65622  -76.17504
# 1                 FS2      CHLA          2.03  UG/L  39.65622  -76.17504
# 2                 FS1      CHLA         17.73  UG/L  39.65622  -76.17504
# 3                 FS2      CHLA         17.94  UG/L  39.65622  -76.17504
# 4                 FS1      CHLA         11.75  UG/L  39.65622  -76.17504
#
#              Datetime
# 0 2009-03-04 09:26:00
# ...

# %%
#Check numeric
# pd.to_numeric(cleaned_data['MeasureValue'], errors='coerce').isna().sum()
cleaned_data['MeasureValue'].isna().sum()
cleaned_data[cleaned_data['MeasureValue'].isna()]['Parameter'].value_counts()
#Drop the 212 rows with NAN values for MeasureValue
cleaned_data = cleaned_data.dropna(subset=['MeasureValue'])
cleaned_data['MeasureValue'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No NANs is very good.

# %% [markdown]
# ### Pivot Table of Parameters:
# The table is currently in long format, but for machine learning, correlation, and for further exploration of the data it is better for it to be in wide format. This can be achieved with a pivot table.

# %% [markdown]
# #### Unit Harmonization:
# Before creating the pivot table which will get rid of the unit column it is important to ensure that all of the values for a parameter are all recoreded in the same unit.

# %%
cleaned_data.groupby('Parameter')['Unit'].unique()
# Out:
# Parameter
# CHLA            [UG/L]
# DIN             [MG/L]
# DO              [MG/L]
# DOC             [MG/L]
# DON             [MG/L]
# DOP             [MG/L]
# FSS             [MG/L]
# KD               [1/M]
# NH4F            [MG/L]
# NO23F           [MG/L]
# NO2F            [MG/L]
# NO3F            [MG/L]
# PC              [MG/L]
# PH                [SU]
# PHEO            [UG/L]
# PIP             [MG/L]
# PN              [MG/L]
# PO4F            [MG/L]
# POC             [MG/L]
# PON             [MG/L]
# PP              [MG/L]
# SALINITY         [PPT]
# SECCHI             [M]
# SPCOND      [UMHOS/CM]
# TDN             [MG/L]
# TDP             [MG/L]
# TKNF            [MG/L]
# TN              [MG/L]
# TOC             [MG/L]
# TON             [MG/L]
# TP              [MG/L]
# TSS             [MG/L]
# VSS             [MG/L]
# WTEMP          [DEG C]
# Name: Unit, dtype: object

# %% [markdown]
# We can see that the units are consistent for every parameter and now we can pivot.

# %% [markdown]
# #### Create pivot table:
# To keep track of the units that each parameter is recorded in, every parmeter will hav the corresponding unit appended to it. Now we can create the pivot table with all of the columns that we want to keep as the index. Reset the index and columns name to ensure that the pivot table does not cause any errors when exporting.

# %%
#Pivot
cleaned_data['Parameter_with_units'] = cleaned_data['Parameter'] + '(' + cleaned_data['Unit'].fillna('') + ')'
cols_keep = ['MonitoringStation', 'EventId', 'TotalDepth', 'Depth', 'Layer', 'Latitude', 'Longitude', 'Datetime']
wide_data = pd.pivot_table(
    data = cleaned_data,
    index = cols_keep,
    columns = 'Parameter_with_units',
    values = 'MeasureValue',
    aggfunc = 'mean'
)
wide_data = wide_data.reset_index()
wide_data.columns.name = None
wide_data.head()
# Out:
#   MonitoringStation  EventId  TotalDepth  Depth Layer  Latitude  Longitude  \
# 0           BXK0031   2311.0         2.6    0.0    S    38.1355    -75.751
# 1           BXK0031   3313.0         4.0    0.0    S    38.1355    -75.751
# 2           BXK0031   3936.0         2.4    0.0    S    38.1355    -75.751
# 3           BXK0031   6436.0         2.0    0.0    S    38.1355    -75.751
# 4           BXK0031   7127.0         2.6    0.0    S    38.1355    -75.751
#
#              Datetime  CHLA(UG/L)  DIN(MG/L)  ...  TDN(MG/L)  TDP(MG/L)  \
# 0 2006-05-11 09:10:00       13.83     0.1189  ...       1.02     0.0415
# 1 2006-06-22 09:31:00       26.91     0.0145  ...       0.81     0.0331
# 2 2006-07-13 09:15:00       40.87     0.1600  ...       1.10     0.1429
# 3 2007-04-11 09:00:00       22.43     0.0769  ...       0.76     0.0212
# 4 2007-05-09 09:27:00       18.94     0.0953  ...       0.92     0.0417
#
#    TKNF(MG/L)  TN(MG/L)  TOC(MG/L)  TON(MG/L)  TP(MG/L)  TSS(MG/L)  VSS(MG/L)  \
# ...

# %%
wide_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 427775 entries, 0 to 427774
# Data columns (total 42 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   MonitoringStation  427775 non-null  str
#  1   EventId            427775 non-null  float64
#  2   TotalDepth         427775 non-null  float64
#  3   Depth              427775 non-null  float64
#  4   Layer              427775 non-null  str
#  5   Latitude           427775 non-null  float64
#  6   Longitude          427775 non-null  float64
#  7   Datetime           427775 non-null  datetime64[us]
#  8   CHLA(UG/L)         125943 non-null  float64
#  9   DIN(MG/L)          124591 non-null  float64
#  10  DO(MG/L)           396997 non-null  float64
#  11  DOC(MG/L)          68245 non-null   float64
#  12  DON(MG/L)          122669 non-null  float64
#  13  DOP(MG/L)          122702 non-null  float64
#  14  FSS(MG/L)          2798 non-null    float64
# ...

# %% [markdown]
# ### Wide Table Cleaning:
# As shown there are a ton of NAN values, in multiple of the rows, this is likely due to some of the parameters not being collected every time, since nitrogen, nitrate, nitrite, and ammonium are the main purpose of this study we will thin the rows down based on those parameters. If there is a NAN for any of those parameters that row will be dropped. If a parameter is NAN values in roughly 50% or more of the rows with non-NAN values for the important parameters mentioned previously then they will be dropped from the table, since it is hard to get an accurate estimate of the actual values for those parameters at specific rows.

# %%
important_params = ['WTEMP(DEG C)', 'PH(SU)', 'SALINITY(PPT)', 'DO(MG/L)', 'NO23F(MG/L)', 'TN(MG/L)', 'NH4F(MG/L)']
wide_cleaned_data = wide_data.dropna(subset = important_params)
wide_cleaned_data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 119649 entries, 0 to 427774
# Data columns (total 42 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   MonitoringStation  119649 non-null  str
#  1   EventId            119649 non-null  float64
#  2   TotalDepth         119649 non-null  float64
#  3   Depth              119649 non-null  float64
#  4   Layer              119649 non-null  str
#  5   Latitude           119649 non-null  float64
#  6   Longitude          119649 non-null  float64
#  7   Datetime           119649 non-null  datetime64[us]
#  8   CHLA(UG/L)         117302 non-null  float64
#  9   DIN(MG/L)          119546 non-null  float64
#  10  DO(MG/L)           119649 non-null  float64
#  11  DOC(MG/L)          63427 non-null   float64
#  12  DON(MG/L)          118865 non-null  float64
#  13  DOP(MG/L)          117787 non-null  float64
#  14  FSS(MG/L)          2691 non-null    float64
# ...

# %% [markdown]
# The table still has 119,649 rows of data, additionally the tabel went from a sparse matrix which can be tricky for further analysis and machine learning to a matrix with relatively few missing values.

# %% [markdown]
# #### Drop any columns with too many NANs:
# As mentioned above it can be difficult to get a true sense of the values with too many NANs in the table relative to the total number of rows which is 119,649. These include:
# * VSS (Volatile Suspended Solids): Only has 6,767 rows with actual data.
# * TKNF (Total Kjeldahl Nitrogen): Only has 2,409 rows with actual data.
# * TOC (Total Organic Carbon): Only has 21,283 rows with actual data.
# * SECCHI (Secchi Depth): Only has 21,435 rows with actual data.
# * POC (Total Suspended Organic Carbon): Only has 21,100 rows with actual data.
# * PON (Particulate Organic Nitrogen): Only has 24,083 rows with actual data.
# * KD  (Light Attenuation): Has 0 rows with actual data.
# * FSS (Fixed Suspended Solids): Only has 2,691 rows with actual data.
# * DOC (Dissolved Organic Carbon): Only has 63,427 rows with actual data.
# * PIP (Particulate Inorganic Phosphorus): Only has 1,524 rows with actual data.
#
# These will all be removed from the cleaned wide data.

# %%
wide_cleaned_data = wide_cleaned_data.drop(columns = ['VSS(MG/L)', 'TKNF(MG/L)', 'TOC(MG/L)', 'SECCHI(M)', 'POC(MG/L)', 'PON(MG/L)', 'KD(1/M)', 'FSS(MG/L)', 'DOC(MG/L)', 'PIP(MG/L)'])
wide_cleaned_data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 119649 entries, 0 to 427774
# Data columns (total 32 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   MonitoringStation  119649 non-null  str
#  1   EventId            119649 non-null  float64
#  2   TotalDepth         119649 non-null  float64
#  3   Depth              119649 non-null  float64
#  4   Layer              119649 non-null  str
#  5   Latitude           119649 non-null  float64
#  6   Longitude          119649 non-null  float64
#  7   Datetime           119649 non-null  datetime64[us]
#  8   CHLA(UG/L)         117302 non-null  float64
#  9   DIN(MG/L)          119546 non-null  float64
#  10  DO(MG/L)           119649 non-null  float64
#  11  DON(MG/L)          118865 non-null  float64
#  12  DOP(MG/L)          117787 non-null  float64
#  13  NH4F(MG/L)         119649 non-null  float64
#  14  NO23F(MG/L)        119649 non-null  float64
# ...

# %%
wide_cleaned_data.head()
# Out:
#   MonitoringStation  EventId  TotalDepth  Depth Layer  Latitude  Longitude  \
# 0           BXK0031   2311.0         2.6    0.0    S    38.1355    -75.751
# 1           BXK0031   3313.0         4.0    0.0    S    38.1355    -75.751
# 2           BXK0031   3936.0         2.4    0.0    S    38.1355    -75.751
# 3           BXK0031   6436.0         2.0    0.0    S    38.1355    -75.751
# 4           BXK0031   7127.0         2.6    0.0    S    38.1355    -75.751
#
#              Datetime  CHLA(UG/L)  DIN(MG/L)  ...  PP(MG/L)  SALINITY(PPT)  \
# 0 2006-05-11 09:10:00       13.83     0.1189  ...    0.0364           6.62
# 1 2006-06-22 09:31:00       26.91     0.0145  ...    0.0720          10.41
# 2 2006-07-13 09:15:00       40.87     0.1600  ...    0.1162           3.22
# 3 2007-04-11 09:00:00       22.43     0.0769  ...    0.0501           7.24
# 4 2007-05-09 09:27:00       18.94     0.0953  ...    0.0733           5.39
#
# ...

# %% [markdown]
# ### Allow For Data to be proccessed based on the time is was collected:
# Add columns for Year and Month so that data can be proccessed easily based on the year and the month that the data was collected.

# %%
wide_cleaned_data['Year'] = wide_cleaned_data['Datetime'].dt.year
wide_cleaned_data['Month'] = wide_cleaned_data['Datetime'].dt.month
final_df = wide_cleaned_data.copy()
final_df.head()
# Out:
#   MonitoringStation  EventId  TotalDepth  Depth Layer  Latitude  Longitude  \
# 0           BXK0031   2311.0         2.6    0.0    S    38.1355    -75.751
# 1           BXK0031   3313.0         4.0    0.0    S    38.1355    -75.751
# 2           BXK0031   3936.0         2.4    0.0    S    38.1355    -75.751
# 3           BXK0031   6436.0         2.0    0.0    S    38.1355    -75.751
# 4           BXK0031   7127.0         2.6    0.0    S    38.1355    -75.751
#
#              Datetime  CHLA(UG/L)  DIN(MG/L)  ...  SPCOND(UMHOS/CM)  \
# 0 2006-05-11 09:10:00       13.83     0.1189  ...           12000.0
# 1 2006-06-22 09:31:00       26.91     0.0145  ...           17970.0
# 2 2006-07-13 09:15:00       40.87     0.1600  ...            6370.0
# 3 2007-04-11 09:00:00       22.43     0.0769  ...           13000.0
# 4 2007-05-09 09:27:00       18.94     0.0953  ...           10000.0
#
#    TDN(MG/L)  TDP(MG/L)  TN(MG/L)  TON(MG/L)  TP(MG/L)  TSS(MG/L)  \
# ...

# %%
parameters_cleaned = [column for column in final_df.columns if column.endswith(')')]

# %% [markdown]
# # Data Exploration:
# Univariate Analysis, relationhip exploraion, feature engineering prep.

# %% [markdown]
# ### Univariate Analysis:
# Understanding the shape of all of the parameters is important for continued analysis and to prepare it to be used to train machine learning models. Things like the skew, the mean, variance, etc. is very imporant.

# %%
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(20,20))
axes_flat = axes.flatten()
for column, ax in zip(parameters_cleaned, axes_flat):
    ax.hist(final_df[column], bins = 50)
    ax.set_title(column)
plt.tight_layout()
plt.show()

# %%
#Can clean up a bit with a log tranform
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(20,20))
axes_flat = axes.flatten()
for column, ax in zip(parameters_cleaned, axes_flat):
    ax.hist(final_df[column], bins = 50, log=True)
    ax.set_title(column)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Exploring Outliers:
# Here we can see that some of the graphs have huge outliers, and even more interstingly some of the graphs have huge outliers without any data leading up to the ouliers. This appears in the graph for TN, TON, NO2F, CHLA, DOP, PHEO, WTEMP, TSS, TP, TDP, PO4F, and PH to varying degrees. These points need to be invetigated further to find out where they are coming from, and to ensure they were not caused by an error.

# %%
### Starting with TN
final_df[final_df['TN(MG/L)'] > 150].transpose()
# Out:
#                                 214949
# MonitoringStation                EE2.1
# EventId                       101858.0
# TotalDepth                         7.5
# Depth                              2.0
# Layer                               AP
# Latitude                       38.6549
# Longitude                     -76.2643
# Datetime           1987-07-21 10:15:00
# CHLA(UG/L)                       13.18
# DIN(MG/L)                        0.068
# DO(MG/L)                           7.4
# DON(MG/L)                        0.452
# DOP(MG/L)                         0.03
# NH4F(MG/L)                       0.048
# NO23F(MG/L)                       0.02
# NO2F(MG/L)                       0.004
# NO3F(MG/L)                       0.016
# PC(MG/L)                           NaN
# PH(SU)                             7.9
# PHEO(UG/L)                        0.04
# PN(MG/L)                           NaN
# PO4F(MG/L)                        0.01
# PP(MG/L)                          0.06
# ...

# %% [markdown]
# We can see that there is only one row with over 150 MG/L for TN, and that the other parameters for this same sample do not match up with a high total nitrogen, NO23F and NH4F are not even above the global average for those parameters. This is very likely bad data that can be thrown away. This is also the same data point witht the high TON.

# %%
### Next NO2F
final_df[final_df['NO2F(MG/L)'] > 1.50].transpose()
# Out:
#                                 396981               396982
# MonitoringStation                WT4.1                WT4.1
# EventId                       101249.0             101249.0
# TotalDepth                         1.9                  1.9
# Depth                              0.5                  0.9
# Layer                               S                    B
# Latitude                      39.27755             39.27755
# Longitude                    -76.44368            -76.44368
# Datetime           1987-06-03 11:20:00  1987-06-03 11:20:00
# CHLA(UG/L)                   158.49001               165.97
# DIN(MG/L)                        2.072                 2.08
# DO(MG/L)                           7.8                  8.0
# DON(MG/L)                        0.778                 0.77
# DOP(MG/L)                        0.017                0.016
# NH4F(MG/L)                       0.172                 0.18
# NO23F(MG/L)                        1.9                  1.9
# ...

# %% [markdown]
# Nothing from these values stick out showing that they are errors, to further review we will look at the temporal and temporal data around when are where this data appeared. Both of these data points are from monitoring station WT4.1, it is the only monitoring station on the Back River. So we cannot get any other data points from that period of time on the same river, we can check rivers that are close to it, as well as the bay and we can check the same points in the days leading up to and the days following the datapoints.

# %%
#Spatial locality:
#List of monitoring sites that are close to the 
wt_close_stations = ['WT4.1', 'WT5.1', 'WT3.1', 'HOK0005', 'FRG0018', 'NOM0007', 'MDR0028', 'WT2.1', 'CB3.2', 'CB3.1', 'GUN0125', 'PAT0176']
target_date = pd.to_datetime(final_df.loc[396981,:]['Datetime'])
duration = pd.Timedelta(days=30)
close_stations_list = final_df[(final_df['MonitoringStation'].isin(wt_close_stations)) &
    (final_df['Datetime'] >= (target_date - duration)) &
    (final_df['Datetime'] <= (target_date + duration))
    ]
close_stations_list = close_stations_list.sort_values(by='Datetime')
close_stations_list[['NO2F(MG/L)', 'NH4F(MG/L)', 'NO3F(MG/L)', 'NO23F(MG/L)', 'MonitoringStation', 'Datetime']]
# Out:
#         NO2F(MG/L)  NH4F(MG/L)  NO3F(MG/L)  NO23F(MG/L) MonitoringStation  \
# 20024       0.0106       0.062      0.8894        0.900             CB3.1
# 20026       0.0118       0.072      0.8082        0.820             CB3.1
# 20030       0.0101       0.126      0.3979        0.408             CB3.1
# 20033       0.0098       0.147      0.2812        0.291             CB3.1
# 28524       0.0070       0.168      0.1880        0.195             CB3.2
# 28521       0.0109       0.144      0.3191        0.330             CB3.2
# 28516       0.0132       0.098      0.7268        0.740             CB3.2
# 402349      0.0100       0.228      0.3200        0.330             WT5.1
# 402346      0.0100       0.224      0.3300        0.340             WT5.1
# 402341      0.0290       0.750      0.7310        0.760             WT5.1
# 402336      0.0295       0.825      0.7605        0.790             WT5.1
# 396979      0.0790       7.800      0.6110        0.690             WT4.1
# ...

# %% [markdown]
# While the monitoring sites near the back river do not have values as high as NO23F, this does not mean that the value in the Back river was incorrect, this data should be kept.

# %%
#next is CHLA
final_df[final_df['CHLA(UG/L)'] >= 700].transpose()
# Out:
#                                 307258
# MonitoringStation                LE1.1
# EventId                        73502.0
# TotalDepth                        12.5
# Depth                              0.5
# Layer                               S
# Latitude                      38.42535
# Longitude                    -76.60176
# Datetime           2003-05-29 10:15:00
# CHLA(UG/L)                   722.67999
# DIN(MG/L)                       0.0643
# DO(MG/L)                          10.8
# DON(MG/L)                       0.4757
# DOP(MG/L)                       0.0171
# NH4F(MG/L)                       0.009
# NO23F(MG/L)                     0.0553
# NO2F(MG/L)                      0.0062
# NO3F(MG/L)                      0.0491
# PC(MG/L)                          48.7
# PH(SU)                             8.7
# PHEO(UG/L)                       8.224
# PN(MG/L)                          6.46
# PO4F(MG/L)                      0.0168
# PP(MG/L)                        1.0981
# ...

# %% [markdown]
# This data point shows a potential algal bloom instead of bad data. For exmaple not only is the chorophyll extremely high at 722.68, but the PH is at 8.7, the dissolved oxygen is 10.8 which is higher then usual. TON is high and makes up most of TN, which might be due to almost all of the nitrogen being trapped in the algae bodies. This data should be kept and likely shows a significant biological event.

# %%
#Now DOP, Which should not be too far into the negative
neg_dop = final_df[final_df['DOP(MG/L)'] < 0]
neg_dop[['DOP(MG/L)', 'TDP(MG/L)', 'PO4F(MG/L)', 'MonitoringStation']].sort_values(by='DOP(MG/L)').head(10)
# Out:
#         DOP(MG/L)  TDP(MG/L)  PO4F(MG/L) MonitoringStation
# 221454     -1.200      0.140       1.340             EE2.2
# 368325     -0.375      0.065       0.440             TF1.3
# 368742     -0.150      0.090       0.240             TF1.4
# 208425     -0.149      0.027       0.176             EE1.1
# 400054     -0.128      0.072       0.200             WT5.1
# 208427     -0.121      0.037       0.158             EE1.1
# 417315     -0.107      0.293       0.400             WT8.1
# 368323     -0.090      0.060       0.150             TF1.3
# 376922     -0.090      0.040       0.130             TF1.7
# 226181     -0.090      0.020       0.110             EE3.0

# %% [markdown]
# All of these values should be thrown away since they are basically impossible, since TDP is the total dissolved phosphorus and phosphate is part of the total. So PO4F should not be greater than TDP, and therfore a negative DOP value greater than 0.01 should be thrown out.

# %%
#Next is PHEO
final_df[final_df['PHEO(UG/L)'] > 200].transpose()
# Out:
#                                 397453
# MonitoringStation                WT4.1
# EventId                       460942.0
# TotalDepth                         1.2
# Depth                              0.8
# Layer                               B
# Latitude                      39.27755
# Longitude                    -76.44368
# Datetime           2019-12-11 13:09:00
# CHLA(UG/L)                   168.74001
# DIN(MG/L)                       0.0103
# DO(MG/L)                          15.4
# DON(MG/L)                       0.6797
# DOP(MG/L)                       0.0153
# NH4F(MG/L)                       0.013
# NO23F(MG/L)                     0.0007
# NO2F(MG/L)                       0.001
# NO3F(MG/L)                     -0.0005
# PC(MG/L)                          14.7
# PH(SU)                             8.8
# PHEO(UG/L)                     205.804
# PN(MG/L)                           2.4
# PO4F(MG/L)                      0.0172
# PP(MG/L)                          0.17
# ...

# %% [markdown]
# This data point is likely real and shows an algal bloom with NO3 having a slight negative due to some sensor noise, but The PH is high and chorophyll is also very high. This suggests the algal bloom is dying off in this stage (a crashing bloom). This data point should be kept with NO23F value changes to 0.

# %%
#Next is WTEMP
final_df[final_df['WTEMP(DEG C)'] > 40]
hot_winter = final_df[
    (final_df['WTEMP(DEG C)'] > 35) & 
    (final_df['Month'].isin([10, 11, 12, 1, 2, 3]))
]
hot_winter.transpose()
# Out:
#                                 267101               267106
# MonitoringStation                ET4.1                ET4.1
# EventId                        25298.0              25298.0
# TotalDepth                         5.9                  5.9
# Depth                              0.5                  4.9
# Layer                               S                    B
# Latitude                       39.2437              39.2437
# Longitude                     -75.9249             -75.9249
# Datetime           2005-12-12 08:39:00  2005-12-12 08:39:00
# CHLA(UG/L)                         1.0                 3.99
# DIN(MG/L)                        2.653                2.697
# DO(MG/L)                          12.1                 12.2
# DON(MG/L)                        0.437                0.543
# DOP(MG/L)                       0.0196               0.0241
# NH4F(MG/L)                       0.133                0.127
# NO23F(MG/L)                       2.52                 2.57
# ...

# %% [markdown]
# These data points should be removed, it is very unlikely (impossible) for the temperature to be 47 degrees celcius, that is boiling, in winter (December). These data points must be removed.

# %%
#Now TSS
final_df[final_df['TSS(MG/L)'] > 1500]
# Out:
#        MonitoringStation  EventId  TotalDepth  Depth Layer  Latitude  \
# 377698             TF2.1   6040.0        19.5    9.1    M   38.70664
# 377700             TF2.1   6040.0        19.5   18.5    B   38.70664
# 381394             TF2.2   6038.0         8.8    7.8    B   38.69067
#
#         Longitude            Datetime  CHLA(UG/L)  DIN(MG/L)  ...  \
# 377698  -77.04876 1996-09-09 13:20:00        5.98      0.886  ...
# 377700  -77.04876 1996-09-09 13:20:00       13.46      0.903  ...
# 381394  -77.11111 1996-09-09 12:55:00       22.43      0.844  ...
#
#         SPCOND(UMHOS/CM)  TDN(MG/L)  TDP(MG/L)  TN(MG/L)  TON(MG/L)  TP(MG/L)  \
# 377698             160.0      1.465      0.079     5.297      4.411       1.9
# 377700             159.0      1.350      0.076     5.165      4.262       2.1
# 381394             158.0      1.328      0.070     7.989      7.145       2.8
#
#         TSS(MG/L)  WTEMP(DEG C)  Year  Month
# 377698     1560.0          21.2  1996      9
# ...

# %% [markdown]
# These are all likely real data points that have high TSS values due to hurricane Fran affecting the levels in the bay. They also have high TP values that would align with the effects of a hurricane and flooding.

# %%
final_df[final_df['TDP(MG/L)'] > 0.4].transpose()
# Out:
#                                 313829               391109  \
# MonitoringStation                LE1.2              TRQ0146
# EventId                       121265.0              54158.0
# TotalDepth                        17.0                  2.4
# Depth                             15.2                  0.0
# Layer                               M                    S
# Latitude                      38.37887             38.46556
# Longitude                    -76.51132            -76.00056
# Datetime           1985-09-16 10:25:00  2003-07-09 09:40:00
# CHLA(UG/L)                         0.9                23.18
# DIN(MG/L)                         0.17                0.668
# DO(MG/L)                           5.4                  3.2
# DON(MG/L)                         0.81                1.262
# DOP(MG/L)                         0.38                0.141
# NH4F(MG/L)                        0.03                 0.48
# NO23F(MG/L)                       0.14                0.188
# ...

# %% [markdown]
# The data from WT4.1 has alreaady been discussed and is likely valid data. The data from station LE1.2 does not make sense as TDP is greater then TP, this does not make sense and means the data is likely not valid and should be dropped. Data from station WT8.3 seems like an error since PO4F is very small 0.004, mening tha DOP makes up 99% of TDP, but the rrest of the data does not match with TN and TDP not being higher then average. Data from site WT8.1 should be deleted since TDN is greater then TN. Finally, TRQ0146 seems to be a valid data point with everything matching up.

# %%
#PO4F
final_df[final_df['PO4F(MG/L)'] > 0.4].transpose()
# Out:
#                                 221454               368325  \
# MonitoringStation                EE2.2                TF1.3
# EventId                       101862.0             121279.0
# TotalDepth                        14.0                  0.0
# Depth                             13.0                  0.0
# Layer                               B                    S
# Latitude                      38.52609             38.81092
# Longitude                    -76.30408            -76.71227
# Datetime           1987-07-21 11:00:00  1985-09-16 14:55:00
# CHLA(UG/L)                         1.2                8.755
# DIN(MG/L)                         3.22                5.245
# DO(MG/L)                           0.4                  9.2
# DON(MG/L)                         -2.2                0.455
# DOP(MG/L)                         -1.2               -0.375
# NH4F(MG/L)                         3.2                0.045
# NO23F(MG/L)                       0.02                  5.2
# ...

# %% [markdown]
# All but the data from WT4.1 can be removed it is not possible due to a part being larger then the whole (total phosphorus or total dissolved P)

# %%
final_df[final_df['PH(SU)'] < 2].transpose()
# Out:
#                                 369212               424560  \
# MonitoringStation                TF1.5              WXT0001
# EventId                        15241.0              67090.0
# TotalDepth                        11.5                  0.6
# Depth                             10.0                  0.0
# Layer                               B                    S
# Latitude                      38.71012             38.78538
# Longitude                    -76.70146            -76.71343
# Datetime           2006-01-17 12:15:00  2002-10-24 13:30:00
# CHLA(UG/L)                        5.98                 2.99
# DIN(MG/L)                        1.198                0.654
# DO(MG/L)                          10.8                  7.2
# DON(MG/L)                        0.232                0.566
# DOP(MG/L)                       0.0138               0.0214
# NH4F(MG/L)                       0.118                0.061
# NO23F(MG/L)                       1.08                0.593
# ...

# %% [markdown]
# The PH's shown in these would have caused huge environmental effects that would have been noticeable by the amount of dead fish.

# %%
final_df.shape
# Out:
# (119649, 34)

# %% [markdown]
# ### Cleaning the rows mentioned previously
# Remove invalid data that was found and mentioned previously.

# %%
remove_row_list = [214949, 221454, 368325, 368742, 208425, 400054, 208427, 417315, 368323, 376922, 226181, 267101, 267106, 313829, 419286, 423302, 221454, 368325, 405810, 405813, 369212, 424560, 424628]
len(remove_row_list)
# Out:
# 23

# %%
final_df.drop(index = remove_row_list, inplace = True)
final_df.shape
# Out:
# (119628, 34)

# %%
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(20,20))
axes_flat = axes.flatten()
for column, ax in zip(parameters_cleaned, axes_flat):
    ax.boxplot(final_df[column].dropna())
    ax.set_title(column)
plt.tight_layout()    
plt.show()

# %%
final_df.describe().drop(columns=['EventId', 'TotalDepth', 'Depth', 'Latitude', 'Longitude', 'Datetime', 'Year', 'Month']).transpose()
# Out:
#                      count          mean       min         25%         50%  \
# CHLA(UG/L)        117281.0     13.082677   0.00000     4.03500      8.0700
# DIN(MG/L)         119525.0      0.461869   0.00180     0.07780      0.2400
# DO(MG/L)          119628.0      7.840088   0.00000     6.00000      8.0000
# DON(MG/L)         118846.0      0.349330  -3.02000     0.26800      0.3220
# DOP(MG/L)         117769.0      0.011302  -0.09000     0.00595      0.0090
# NH4F(MG/L)        119628.0      0.071991   0.00100     0.01300      0.0380
# NO23F(MG/L)       119628.0      0.390339   0.00040     0.02500      0.1480
# NO2F(MG/L)        119312.0      0.014626   0.00010     0.00340      0.0073
# NO3F(MG/L)        119140.0      0.375447  -0.52600     0.01400      0.1270
# PC(MG/L)           95429.0      1.629953   0.06330     0.81500      1.2400
# PH(SU)            119628.0      7.758186   4.80000     7.50000      7.8000
# ...

# %% [markdown]
# ### Dealing With negative values:
# As shown in the summary table above there are 5 columns with significant negative values including DON, TON, PP, NO3F, and PHEO.
#
# Calculated Variables including DON, TON, and PP are calculated:
# * DON = TDN - DIN (DIN = NH4 + NO3 + NO2)
# * TON = TN - (DIN or NO23 + NH4)
# * PP = TP - TDP
#
# Measured Values including NO3, PHEO.
#
# Minimums in all of these columns are too low to be possible, while some values are likely just sensor noise.

# %%
# List of columns with suspicious negative mins
cols_to_check = ['DON(MG/L)', 'TON(MG/L)', 'PP(MG/L)', 'NO3F(MG/L)', 'PHEO(MG/L)']

# Threshold: We accept tiny noise (e.g. -0.05), but want to see the big errors
# We filter for values LESS than -0.05
deep_negatives = final_df[
    (final_df['DON(MG/L)'] < -0.05) | 
    (final_df['TON(MG/L)'] < -0.05) | 
    (final_df['PP(MG/L)']  < -0.05) |
    (final_df['NO3F(MG/L)'] < -0.05)
]

# Sort by the worst offender (e.g. DON) to see the garbage first
print("Count of deep negative rows:", len(deep_negatives))
deep_negatives[['Datetime', 'MonitoringStation', 'TN(MG/L)', 'TDN(MG/L)', 'DIN(MG/L)', 'TON(MG/L)', 'DON(MG/L)', 'TP(MG/L)', 'TDP(MG/L)', 'PP(MG/L)', 'NO3F(MG/L)']].sort_values(by='DON(MG/L)').head(10)
# Out:
# Count of deep negative rows: 196
#                   Datetime MonitoringStation  TN(MG/L)  TDN(MG/L)  DIN(MG/L)  \
# 397164 1984-11-08 11:30:00             WT4.1     6.250      1.400      4.420
# 307820 1988-06-27 11:20:00             LE1.1     0.830      0.730      2.830
# 208710 1987-06-16 08:30:00             EE1.1     0.915      0.765      2.415
# 219694 1989-08-29 11:16:00             EE2.2     0.915      0.865      2.315
# 400413 1991-06-25 09:45:00             WT5.1     1.240      0.770      2.215
# 206330 1991-06-05 09:05:00             EE1.1     1.010      0.710      1.860
# 400396 1991-06-04 16:16:00             WT5.1     0.970      0.170      1.270
# 219996 1989-07-11 09:40:00             EE2.2     1.015      1.015      2.015
# 402695 1986-08-26 07:50:00             WT5.1     0.840      0.790      1.640
# 207122 1989-08-14 10:20:00             EE1.1     0.890      0.565      1.415
#
#         TON(MG/L)  DON(MG/L)  TP(MG/L)  TDP(MG/L)  PP(MG/L)  NO3F(MG/L)
# ...

# %%
print(f"final_df currently has {len(final_df)} rows.")
# Out:
# final_df currently has 119628 rows.

# %%
#Define cutoffs
cutoffs = {
    'DON(MG/L)': -0.10,
    'TON(MG/L)': -0.10,
    'PP(MG/L)': -0.02,
    'NO3F(MG/L)': -0.05,
    'PHEO(UG/L)': -1.00
}
original_final_df_count = len(final_df)

for col, limit in cutoffs.items():
    final_df = final_df[(final_df[col] >= limit) | (final_df[col].isna())]

dropped_final_df_count = original_final_df_count - len(final_df)

print(f"Dropped {dropped_final_df_count} rows containing impossible negative values.")

cols_to_clip = ['DON(MG/L)', 'TON(MG/L)', 'PP(MG/L)', 'NO3F(MG/L)', 'PHEO(UG/L)', 'DOP(MG/L)', 'NH4F(MG/L)', 'NO2F(MG/L)']

for col in cols_to_clip:
    mask = (final_df[col] < 0) & (final_df[col].notna())
    final_df.loc[mask, col] = 0.0
print("Clipped remaining negative values that were small enough to likely be instrument noise")
# Out:
# Dropped 310 rows containing impossible negative values.
# Clipped remaining negative values that were small enough to likely be instrument noise

# %%
final_df.describe().drop(columns=['EventId', 'TotalDepth', 'Depth', 'Latitude', 'Longitude', 'Datetime', 'Year', 'Month']).transpose()
# Out:
#                      count          mean      min         25%          50%  \
# CHLA(UG/L)        116979.0     13.099067   0.0000     4.04000      8.07000
# DIN(MG/L)         119215.0      0.461466   0.0018     0.07760      0.23975
# DO(MG/L)          119318.0      7.842218   0.0000     6.00000      8.00000
# DON(MG/L)         118550.0      0.349795   0.0000     0.26800      0.32200
# DOP(MG/L)         117499.0      0.011355   0.0000     0.00595      0.00900
# NH4F(MG/L)        119318.0      0.071336   0.0010     0.01300      0.03800
# NO23F(MG/L)       119318.0      0.390591   0.0004     0.02500      0.14800
# NO2F(MG/L)        119011.0      0.014607   0.0001     0.00340      0.00730
# NO3F(MG/L)        118839.0      0.375721   0.0000     0.01400      0.12720
# PC(MG/L)           95413.0      1.629919   0.0633     0.81500      1.24000
# PH(SU)            119318.0      7.758545   4.8000     7.50000      7.80000
# ...

# %% [markdown]
# # Exploratory Data Analysis:

# %%
unique_stations = final_df.groupby(by = ['MonitoringStation'],dropna=True,as_index = False).first()
station_cords = unique_stations[['MonitoringStation', 'Latitude', 'Longitude']]
station_cords
# Out:
#    MonitoringStation  Latitude  Longitude
# 0            BXK0031  38.13550  -75.75100
# 1              CB1.1  39.54794  -76.08481
# 2              CB2.1  39.44149  -76.02599
# 3              CB2.2  39.34873  -76.17579
# 4              CB3.1  39.24950  -76.24050
# ..               ...       ...        ...
# 80           WXT0001  38.78538  -76.71343
# 81           XAK7810  37.96395  -75.65047
# 82           XCI4078  38.23379  -75.86963
# 83           XDJ9007  38.48375  -75.82098
# 84           XFB1986  38.69787  -77.02317
#
# [85 rows x 3 columns]

# %%
gdf = gpd.GeoDataFrame(
    station_cords, 
    geometry=gpd.points_from_xy(station_cords['Longitude'], station_cords['Latitude']),
    crs='EPSG:4326'
)

# %%
gdf = gdf.set_crs(epsg=4326, allow_override=True)
gdf = gdf.to_crs(epsg=3857)

# %%
gdf.drop_duplicates(subset=None, keep='first',inplace=False)
gdf
# Out:
#    MonitoringStation  Latitude  Longitude                          geometry
# 0            BXK0031  38.13550  -75.75100  POINT (-8432562.747 4598585.142)
# 1              CB1.1  39.54794  -76.08481  POINT (-8469722.306 4800465.977)
# 2              CB2.1  39.44149  -76.02599  POINT (-8463174.494 4785109.982)
# 3              CB2.2  39.34873  -76.17579  POINT (-8479850.154 4771747.971)
# 4              CB3.1  39.24950  -76.24050  POINT (-8487053.638 4757473.581)
# ..               ...       ...        ...                               ...
# 80           WXT0001  38.78538  -76.71343  POINT (-8539699.965 4690975.559)
# 81           XAK7810  37.96395  -75.65047  POINT (-8421371.799 4574334.408)
# 82           XCI4078  38.23379  -75.86963  POINT (-8445768.578 4612505.347)
# 83           XDJ9007  38.48375  -75.82098   POINT (-8440352.885 4647990.67)
# 84           XFB1986  38.69787  -77.02317  POINT (-8574180.064 4678485.981)
#
# [85 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize = (8,11))
gdf.plot(ax=ax, color='red', edgecolor='black',markersize=50)
cx.add_basemap(ax, source=cx.providers.CartoDB.Voyager)
ax.set_title("Chesapeake Bay Monitoring Stations", fontsize=16)
ax.set_axis_off()
for x, y, label in zip(gdf.geometry.x, gdf.geometry.y, gdf['MonitoringStation']):
    ax.annotate(label, xy=(x, y), xytext=(3, 3), textcoords="offset points", fontsize=8)
plt.show()

# %%
tributary_boundaries = gpd.read_file('data/tributaries_regions_map.geojson')
tributary_boundaries = tributary_boundaries.to_crs(epsg=3857)
tributary_boundaries.loc[tributary_boundaries['OBJECTID'] == 9, 'straname'] = 'MAINSTEM BAY'
tributary_boundaries = tributary_boundaries[tributary_boundaries['straname'] != 'NOT A STRATEGY SHED']
tributary_boundaries
# Out:
#     OBJECTID  stracode             straname  Shape_Length  Shape_Area  \
# 1          2       1.0        UPPER POTOMAC      8.194279    0.557489
# 3          4       5.0  UPPER WESTERN SHORE      2.879207    0.264326
# 4          5       2.0       MIDDLE POTOMAC      3.220584    0.171340
# 7          8       8.0  UPPER EASTERN SHORE      3.247826    0.311224
# 8          9       0.0         MAINSTEM BAY      5.125533    0.291037
# 9         10       9.0             CHOPTANK      3.024254    0.221232
# 10        11      10.0  LOWER EASTERN SHORE      4.059853    0.473099
# 11        12       7.0        LOWER POTOMAC      3.341571    0.301635
# 12        13       4.0        PATAPSCO/BACK      2.815856    0.183996
# 13        14       3.0             PATUXENT      4.918568    0.257129
# 14        15       6.0  LOWER WESTERN SHORE      3.044206    0.082066
#
#                                              geometry
# 1   MULTIPOLYGON (((-8787809.005 4825740.83, -8787...
# ...

# %%
joined_geodata = gpd.sjoin(gdf, tributary_boundaries, how='inner', predicate='within', lsuffix='MSta', rsuffix='Reg')
# Out:
# array([-8601556.86605453,  4567361.61648032, -8412553.06861118,
#         4803616.53858432])

# %%
fig,ax = plt.subplots(figsize = (8,11))
tributary_boundaries.plot(ax=ax, column ='straname', cmap='bone', legend=True, alpha=0.6)
joined_geodata.plot(ax = ax,color='red',edgecolor='black',markersize=50, zorder=5)
cx.add_basemap(ax, source=cx.providers.CartoDB.Voyager)
ax.set_title("Chesapeake Bay Monitoring Stations", fontsize=16)
minx, miny, maxx, maxy = joined_geodata.total_bounds
buffer = 10000
ax.set_xlim(minx - buffer, maxx + buffer)
ax.set_ylim(miny - buffer, maxy + buffer)
for x, y, label in zip(joined_geodata.geometry.x, joined_geodata.geometry.y, joined_geodata['MonitoringStation']):
    ax.annotate(label, xy=(x, y), xytext=(3, 3), textcoords="offset points", fontsize=8)
ax.set_xlim()
plt.show()

# %% [markdown]
# Geospatial boundaries sourced from the Maryland Department of Natural Resources: Tributary Basins dataset (2026).

# %%
missing_regions = joined_geodata[joined_geodata['straname'].isna()]
missing_regions.shape
# Out:
# (0, 10)

# %% [markdown]
# Great all monitoring sites now have a region

# %%
joined_geodata.head()
# Out:
#   MonitoringStation  Latitude  Longitude                          geometry  \
# 0           BXK0031  38.13550  -75.75100  POINT (-8432562.747 4598585.142)
# 1             CB1.1  39.54794  -76.08481  POINT (-8469722.306 4800465.977)
# 2             CB2.1  39.44149  -76.02599  POINT (-8463174.494 4785109.982)
# 3             CB2.2  39.34873  -76.17579  POINT (-8479850.154 4771747.971)
# 4             CB3.1  39.24950  -76.24050  POINT (-8487053.638 4757473.581)
#
#    index_Reg  OBJECTID  stracode             straname  Shape_Length  \
# 0         10        11      10.0  LOWER EASTERN SHORE      4.059853
# 1          3         4       5.0  UPPER WESTERN SHORE      2.879207
# 2          8         9       0.0         MAINSTEM BAY      5.125533
# 3          8         9       0.0         MAINSTEM BAY      5.125533
# 4          8         9       0.0         MAINSTEM BAY      5.125533
#
#    Shape_Area
# 0    0.473099
# 1    0.264326
# 2    0.291037
# 3    0.291037
# 4    0.291037

# %%
final_df.head()
# Out:
#   MonitoringStation  EventId  TotalDepth  Depth Layer  Latitude  Longitude  \
# 0           BXK0031   2311.0         2.6    0.0    S    38.1355    -75.751
# 1           BXK0031   3313.0         4.0    0.0    S    38.1355    -75.751
# 2           BXK0031   3936.0         2.4    0.0    S    38.1355    -75.751
# 3           BXK0031   6436.0         2.0    0.0    S    38.1355    -75.751
# 4           BXK0031   7127.0         2.6    0.0    S    38.1355    -75.751
#
#              Datetime  CHLA(UG/L)  DIN(MG/L)  ...  SPCOND(UMHOS/CM)  \
# 0 2006-05-11 09:10:00       13.83     0.1189  ...           12000.0
# 1 2006-06-22 09:31:00       26.91     0.0145  ...           17970.0
# 2 2006-07-13 09:15:00       40.87     0.1600  ...            6370.0
# 3 2007-04-11 09:00:00       22.43     0.0769  ...           13000.0
# 4 2007-05-09 09:27:00       18.94     0.0953  ...           10000.0
#
#    TDN(MG/L)  TDP(MG/L)  TN(MG/L)  TON(MG/L)  TP(MG/L)  TSS(MG/L)  \
# ...

# %%
columns_to_merge = joined_geodata[['MonitoringStation','straname']]
final_df = pd.merge(final_df, columns_to_merge, on='MonitoringStation',how='left')
final_df[final_df['straname'].isna()]
# Out:
#       MonitoringStation   EventId  TotalDepth  Depth Layer  Latitude  \
# 40509             CB5.3     182.0        25.0    0.5    S   37.91011
# 40510             CB5.3     182.0        25.0    6.0    AP  37.91011
# 40511             CB5.3     182.0        25.0   12.0    BP  37.91011
# 40512             CB5.3     182.0        25.0   24.0    B   37.91011
# 40513             CB5.3     359.0        27.0    0.5    S   37.91011
# ...                 ...       ...         ...    ...   ...       ...
# 42830             CB5.3  699617.0        27.3   26.0    B   37.91011
# 42831             CB5.3  699650.0        27.0    0.5    S   37.91011
# 42832             CB5.3  699650.0        27.0    2.0    AP  37.91011
# 42833             CB5.3  699650.0        27.0   13.0    BP  37.91011
# 42834             CB5.3  699650.0        27.0   26.0    B   37.91011
#
#        Longitude            Datetime  CHLA(UG/L)  DIN(MG/L)  ...  TN(MG/L)  \
# ...

# %%
final_df['Month'] = final_df.Datetime.dt.month
final_df.head()
# Out:
#   MonitoringStation  EventId  TotalDepth  Depth Layer  Latitude  Longitude  \
# 0           BXK0031   2311.0         2.6    0.0    S    38.1355    -75.751
# 1           BXK0031   3313.0         4.0    0.0    S    38.1355    -75.751
# 2           BXK0031   3936.0         2.4    0.0    S    38.1355    -75.751
# 3           BXK0031   6436.0         2.0    0.0    S    38.1355    -75.751
# 4           BXK0031   7127.0         2.6    0.0    S    38.1355    -75.751
#
#              Datetime  CHLA(UG/L)  DIN(MG/L)  ...  TDN(MG/L)  TDP(MG/L)  \
# 0 2006-05-11 09:10:00       13.83     0.1189  ...       1.02     0.0415
# 1 2006-06-22 09:31:00       26.91     0.0145  ...       0.81     0.0331
# 2 2006-07-13 09:15:00       40.87     0.1600  ...       1.10     0.1429
# 3 2007-04-11 09:00:00       22.43     0.0769  ...       0.76     0.0212
# 4 2007-05-09 09:27:00       18.94     0.0953  ...       0.92     0.0417
#
#    TN(MG/L)  TON(MG/L)  TP(MG/L)  TSS(MG/L)  WTEMP(DEG C)  Year  Month  \
# ...

# %%
average_nutrient_months = final_df.groupby(['MonitoringStation', 'Month'])['NO23F(MG/L)'].mean().unstack()
average_nutrient_months.head()
# Out:
# Month                    1         2         3         4         5         6   \
# MonitoringStation
# BXK0031            0.453793  0.489907  0.419493  0.223914  0.146815  0.057453
# CB1.1              1.529716  1.581006  1.417467  1.072897  0.980354  1.014321
# CB2.1              1.408449  1.579886  1.378713  1.084375  0.913332  0.800482
# CB2.2              1.095784  1.191083  1.161490  0.981561  0.814828  0.669667
# CB3.1              0.753877  0.857062  0.868650  0.798082  0.590437  0.402978
#
# Month                    7         8         9         10        11        12
# MonitoringStation
# BXK0031            0.037950  0.028927  0.064256  0.125033  0.223413  0.416936
# CB1.1              1.037599  0.967842  0.980058  1.185139  1.192911  1.293742
# CB2.1              0.679625  0.568044  0.636631  0.879249  1.092486  1.207721
# CB2.2              0.565250  0.471767  0.496783  0.684177  0.834818  0.940373
# ...

# %%
av
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 av
#
# NameError: name 'av' is not defined
